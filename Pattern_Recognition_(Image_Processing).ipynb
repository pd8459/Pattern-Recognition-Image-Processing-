# %% [markdown]
# <a href="https://colab.research.google.com/github/pd8459/Pattern-Recognition-Image-Processing-/blob/main/Pattern_Recognition_(Image_Processing).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# !wget https://raw.githubusercontent.com/Cobslab/imageBible/main/image/like_lenna224.png -O like_lenna.png
# Out:
# --2025-03-19 12:25:06--  https://raw.githubusercontent.com/Cobslab/imageBible/main/image/like_lenna224.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30283 (30K) [image/png]
# Saving to: ‘like_lenna.png’
#
# like_lenna.png      100%[===================>]  29.57K  --.-KB/s    in 0.004s
#
# 2025-03-19 12:25:06 (8.12 MB/s) - ‘like_lenna.png’ saved [30283/30283]

# %%
import cv2

# 이미지 불러오기
image = cv2.imread("like_lenna.png", cv2.IMREAD_UNCHANGED)

# 이미지의 채널 수 확인
print("이미지 Shape:", image.shape)
# Out:
# 이미지 Shape: (224, 224)

# %%
import cv2

image = cv2.imread('like_lenna.png', cv2.IMREAD_GRAYSCALE)
if image is not None:
  print("이미지를 읽어왔습니다.")
else:
  print("이미지를 읽어오지 못했습니다.")
print(f"변수 타입: {type(image)}")
# Out:
# 이미지를 읽어왔습니다.
# 변수 타입: <class 'numpy.ndarray'>

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=L size=224x224>

# %%
print(f"이미지 배열의 형태: {image.shape}")
# Out:
# 이미지 배열의 형태: (183, 275)

# %%
image_small = cv2.resize(image,(100,100))
cv2_imshow(image_small)
# Out:
# <PIL.Image.Image image mode=L size=100x100>

# %%
image_big = cv2.resize(image, dsize=None, fx=2, fy=2,)
cv2_imshow(image_big)
# Out:
# <PIL.Image.Image image mode=L size=550x366>

# %%
image_fliped = cv2.flip(image,0)
cv2_imshow(image_fliped)
# Out:
# <PIL.Image.Image image mode=L size=275x183>

# %%
image_fliped = cv2.flip(image,1)
cv2_imshow(image_fliped)
# Out:
# <PIL.Image.Image image mode=L size=275x183>

# %%
height, width = image.shape
matrix = cv2.getRotationMatrix2D((width/2, height/2), 90,1)
result = cv2.warpAffine(image, matrix, (width, height))
cv2_imshow(result)
# Out:
# <PIL.Image.Image image mode=L size=275x183>

# %%
matrix = cv2.getRotationMatrix2D((width/2, height/2),30,1)
result = cv2.warpAffine(image, matrix, (width, height), borderValue = 200)
cv2_imshow(result)
# Out:
# <PIL.Image.Image image mode=L size=275x183>

# %%
cv2_imshow(image[:100, :100])
# Out:
# <PIL.Image.Image image mode=L size=100x100>

# %%
cv2_imshow(image[50:150, 50:150])
# Out:
# <PIL.Image.Image image mode=L size=100x100>

# %%
croped_image = image[50:150,50:150]
croped_image[:] = 200
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=L size=275x183>

# %%
image = cv2.imread('like_lenna.png', cv2.IMREAD_GRAYSCALE)
croped_image = image[50:150, 50:150].copy()
croped_image[:] = 200
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=L size=224x224>

# %%
import tensorflow as tf
image_path = tf.keras.utils.get_file('/content/image.jpg', origin=url)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-a059a1c8fd01> in <cell line: 0>()
#       1 import tensorflow as tf
# ----> 2 image_path = tf.keras.utils.get_file('fname=/content/image.jpg', origin=url)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/file_utils.py in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir, force_download)
#     239     else:
#     240         if os.sep in fname:
# --> 241             raise ValueError(
#     242                 "Paths are no longer accepted as the `fname` argument. "
#     243                 "To specify the file's parent directory, use "
#
# ValueError: Paths are no longer accepted as the `fname` argument. To specify the file's parent directory, use the `cache_dir` argument. Received: fname=fname=/content/image.jpg

# %%
url = 'https://cobslab.com/wp-content/uploads/2022/02/ai-009-1.jpg'

import tensorflow as tf
image_path = tf.keras.utils.get_file("image.jpg", origin=url)
# Out:
# Downloading data from https://cobslab.com/wp-content/uploads/2022/02/ai-009-1.jpg
# 116520/116520 ━━━━━━━━━━━━━━━━━━━━ 1s 4us/step

# %%
image = tf.io.read_file(image_path)
image
# Out:
# <tf.Tensor: shape=(), dtype=string, numpy=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\
x08\x00\x00\x00\x00\x00\x00\x00\x00\x00\t\xb3]\x98\xe3m\xad\xb8\xcfFt\x94\xaeV\x88/\xab]\xb8P\x99gk.y\x85E\xb3Em\x19\xe5\xee\xb6W4\x19\xe2I\t\xd1~L\x95)=.r\x81!3+\x00\x10@\x00\x00\x00\x00\x00\x00\x00\x00\x13f\xab\xb1Wf\xce\xcd\xb5eD\xaf=6Nu\x88\x1euNYw\xb1\xc1+\xad\x11_F\x8c\xf4]~:\x9a\xcdv\xed\xbf\x17/*\x930\xa5\xdb\x85\xb6\xc8+\xbf-$\x10\x04\x00L%0\x00\x00\x00\x00\x00\x00\x00\x00\x12\xfa\xb4c[5\xce\x8ajZ\xe1\xef\xb2\xa5\x02^tl\\\xf5W]\x15*,D\x0f\xa3^j+\x ...

# %%
image = tf.image.decode_jpeg(image,channels=3)
image
# Out:
# <tf.Tensor: shape=(952, 1048, 3), dtype=uint8, numpy=
# array([[[ 1, 10, 39],
#         [ 1, 10, 39],
#         [ 1, 10, 39],
#         ...,
#         [ 1, 10, 39],
#         [ 1, 10, 39],
#         [ 1, 10, 39]],
#
#        [[ 1, 10, 39],
#         [ 1, 10, 39],
#         [ 1, 10, 39],
#         ...,
#         [ 1, 10, 39],
#         [ 1, 10, 39],
#         [ 1, 10, 39]],
#
#        [[ 1, 10, 39],
#         [ 1, 10, 39],
#         [ 1, 10, 39],
#         ...,
#         [ 1, 10, 39],
#         [ 1, 10, 39],
#         [ 1, 10, 39]],
#
#        ...,
#
#        [[ 1, 10, 39],
#         [ 1, 10, 39],
#         [ 1, 10, 39],
#         ...,
#         [ 1, 10, 39],
#         [ 1, 10, 39],
#         [ 1, 10, 39]],
#
#        [[ 1, 10, 39],
#         [ 1, 10, 39],
#         [ 1, 10, 39],
#         ...,
#         [ 1, 10, 39],
#         [ 1, 10, 39],
#         [ 1, 10, 39]],
#
#        [[ 1, 10, 39],
#         [ 1, 10, 39],
#         [ 1, 10, 39],
#         ...,
#         [ 1, 10, 39],
#         [ 1, 10, 39],
#         [ 1, 10, 39]]], dtype=uint8)>

# %%
import matplotlib.pyplot as plt
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
rgb_image = tf.random.uniform([100,100,3], maxval=255, dtype=tf.float32)

print(rgb_image)
# Out:
# tf.Tensor(
# [[[141.5342    70.4757   238.67957 ]
#   [ 14.392625  74.38627  151.1302  ]
#   [ 58.256195  49.7255   215.73753 ]
#   ...
#   [ 94.695724 219.00146   25.896645]
#   [ 22.140621 115.740814 153.75325 ]
#   [ 62.135483  24.101044   7.586399]]
#
#  [[ 11.771981  11.180155 141.37263 ]
#   [218.35039  238.1722   238.78152 ]
#   [ 75.1144    72.539444 250.1513  ]
#   ...
#   [ 60.556774  29.623606  76.24622 ]
#   [ 50.970554 187.72433  120.04356 ]
#   [175.20811  164.6801   213.37712 ]]
#
#  [[221.219     76.84063  191.24344 ]
#   [ 48.182175  52.90982  100.72551 ]
#   [158.7335   115.43151  113.23973 ]
#   ...
#   [124.40207  188.09714   64.989494]
#   [136.13162  213.60959  211.89256 ]
#   [232.37137   19.665495  39.180397]]
#
#  ...
#
#  [[160.31595  170.5184   105.77635 ]
#   [ 21.024668 174.53448  248.00275 ]
#   [185.7782    94.45831  168.84004 ]
#   ...
#   [109.71148   31.800343  65.58895 ]
#   [159.2268   229.76297   86.134384]
#   [192.0613   250.95288   51.03111 ]]
#
#  [[ 75.50675  178.44067   69.06609 ]
#   [  7.570835  27.387684 118.8468  ]
#   [209.39136  190.01129   61.851803]
#   ...
#   [179.43008  208.69438   82.30334 ]
#   [247.65031  178.71927   58.981407]
#   [ 78.50671   13.676956 116.13578 ]]
#
#  [[ 85.70239   94.1522    34.549175]
#   [  8.15339  238.01862  114.39803 ]
#   [ 69.89804  129.71967  177.04405 ]
#   ...
#   [102.025375   8.854406  73.600685]
#   [ 83.33503  162.75122  205.491   ]
#   [ 48.133995 170.94917  234.50912 ]]], shape=(100, 100, 3), dtype=float32)

# %%
plt.imshow(rgb_image)
plt.title('RGB Image')
plt.axis('off')
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.021826029..254.99963].

# %%
grayscale_image = tf.image.rgb_to_grayscale(rgb_image)

print(grayscale_image.shape)
plt.imshow(grayscale_image.numpy().squeeze(), cmap = 'gray')
plt.title('Grayscale Image')
plt.axis('off')
plt.show()
# Out:
# (100, 100, 1)

# %%
R = rgb_image[0][0][0] * 0.299
G = rgb_image[0][0][1] * 0.587
B = rgb_image[0][0][2] * 0.114
Y = R+G+B
print(grayscale_image[0][0],Y)
# Out:
# tf.Tensor([110.883286], shape=(1,), dtype=float32) tf.Tensor(110.89743, shape=(), dtype=float32)

# %%
hsv_image = tf.image.rgb_to_hsv(rgb_image)

hue_channel = hsv_image[:,:,0]

plt.imshow(hue_channel, cmap = 'hsv')
plt.title('Hue Channel of HSV Image')
plt.axis('off')
plt.colorbar(label='Hue Value')
plt.show()

# %%
normalized_image = rgb_image / 255.0
rgb_image[0][0] , normalized_image[0][0]
# Out:
# (<tf.Tensor: shape=(3,), dtype=float32, numpy=array([141.5342 ,  70.4757 , 238.67957], dtype=float32)>,
#  <tf.Tensor: shape=(3,), dtype=float32, numpy=array([0.55503607, 0.2763753 , 0.9359983 ], dtype=float32)>)

# %%
standartdized_image = (rgb_image - tf.reduce_mean(rgb_image)) / tf.math.reduce_std(rgb_image)
rgb_image[0][0], standartdized_image[0][0]
# Out:
# (<tf.Tensor: shape=(3,), dtype=float32, numpy=array([141.5342 ,  70.4757 , 238.67957], dtype=float32)>,
#  <tf.Tensor: shape=(3,), dtype=float32, numpy=array([ 0.19402161, -0.769195  ,  1.5108527 ], dtype=float32)>)

# %%
import numpy as np
import cv2

def generate_salt_noise(image):
  num_salt = np.ceil(0.05 * image.size)
  coords = [np.random.randint(0,i-1,int(num_salt))
            for i in image.shape]
  salted_image = image.copy()
  salted_image[coords[0], coords[1]] = 255
  return salted_image

def generate_pepper_noise(image):
    num_pepper = np.ceil(0.05 * image.size)
    coords = [np.random.randint(0,i-1,int(num_pepper))
              for i in image.shape]
    peppered_image = image.copy()
    peppered_image[coords[0], coords[1]] = 0
    return peppered_image

# %%
# !wget https://raw.githubusercontent.com/Cobslab/imageBible/main/image/like_lenna.png

lenna_image = cv2.imread('like_lenna.png', cv2.IMREAD_GRAYSCALE)

salted_lenna = generate_salt_noise(lenna_image)
peppered_lenna = generate_pepper_noise(salted_lenna)
filtered_lenna = cv2.medianBlur(peppered_lenna,5)

fig, axes = plt.subplots(1,4,figsize=(20,6))
# Out:
# --2025-03-19 06:04:35--  https://raw.githubusercontent.com/Cobslab/imageBible/main/image/like_lenna.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1462729 (1.4M) [image/png]
# Saving to: ‘like_lenna.png.5’
#
# like_lenna.png.5    100%[===================>]   1.39M  --.-KB/s    in 0.05s
#
# 2025-03-19 06:04:35 (29.4 MB/s) - ‘like_lenna.png.5’ saved [1462729/1462729]

# %%
import matplotlib.pyplot as plt

axes[0].imshow(lenna_image, cmap='gray')
axes[0].set_title('Original Lenna Image')
axes[0].axis('off')

axes[1].imshow(salted_lenna, cmap='gray')
axes[1].set_title('Salted Lenna Image')
axes[1].axis('off')

axes[2].imshow(peppered_lenna, cmap='gray')
axes[2].set_title('Salted & Peppered Lenna')
axes[2].axis('off')
# Out:
# (np.float64(-0.5), np.float64(223.5), np.float64(223.5), np.float64(-0.5))

# %%
axes[3].imshow(filtered_lenna,cmap='gray')
axes[3].set_title('Median Filtered Lenna')
axes[3].axis('off')

plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('like_lenna.png', cv2.IMREAD_GRAYSCALE)
mean =0
sigma = 1
gaussian_noise=np.random.normal(mean, sigma, image.shape).astype('uint8')
noise_image = cv2.add(image, gaussian_noise)

plt.imshow(noise_image, cmap='gray')
plt.title('Noisy Image')
plt.axis('off')
plt.show()

# %%
sigma_value = [1,5,10]
denoised_images = []

for sigma in sigma_value:
    denoised = cv2.GaussianBlur(noise_image,(0,0),sigma )
    denoised_images.append(denoised)

fig,axes = plt.subplots(1,4,figsize=(20,10))

axes[0].imshow(noise_image, cmap='gray')
axes[0].set_title('Noisy Image')
axes[0].axis('off')

for ax, img, sigma in zip(axes[1:], denoised_images, sigma_value):
  ax.imshow(img, cmap='gray')
  ax.set_title(f'Denoised (o={sigma})')
  ax.axis('off')

plt.tight_layout()
plt.show()

# %%
# !wget https://raw.githubusercontent.com/Cobslab/imageBible/main/image/like_lenna.png -O like_lenna.png
# Out:
# --2025-03-19 12:25:44--  https://raw.githubusercontent.com/Cobslab/imageBible/main/image/like_lenna.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1462729 (1.4M) [image/png]
# Saving to: ‘like_lenna.png’
#
# like_lenna.png      100%[===================>]   1.39M  --.-KB/s    in 0.07s
#
# 2025-03-19 12:25:45 (19.8 MB/s) - ‘like_lenna.png’ saved [1462729/1462729]

# %%
import cv2
import numpy as np

import matplotlib.pyplot as plt

image_path = "like_lenna.png"
img = cv2.imread(image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.title("Original Image")
plt.show()

# %%
def rotate_image(image, angle, center=None):
  rows, cols, _ = image.shape
  if center is None:
    center = (cols // 2, rows // 2)
  M = cv2.getRotationMatrix2D(center, angle, 1)
  rotate = cv2.warpAffine(image, M, (cols,rows))
  return rotate

rotated_img = rotate_image(img,45)
plt.imshow(rotated_img)
plt.title("Rotated Image")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread("like_lenna.png", cv2.IMREAD_GRAYSCALE)

blurred_image = cv2.GaussianBlur(image, (5,5),1.4)

canny_edges = cv2.Canny(blurred_image, threshold1=50, threshold2=150)

# %%
fig, axes = plt.subplots(1,3,figsize=(15,5))
axes[0].imshow(image, cmap='gray')
axes[0].axis('off')
axes[0].set_title('Original Image')
axes[1].imshow(blurred_image, cmap='gray')
axes[1].axis('off')
axes[1].set_title('Gaussian Blurred Image')
axes[2].imshow(canny_edges, cmap='gray')
axes[2].axis('off')
axes[2].set_title('Canny Edge Detection')
# Out:
# Text(0.5, 1.0, 'Canny Edge Detection')

# %%
thresholds = [(10,50), (50,100), (100,150), (150,200)]

canny_results = []
for threshold1, threshold2 in thresholds:
  canny_image = cv2.Canny(blurred_image, threshold1=threshold1, threshold2=
threshold2)
  canny_results.append(canny_image)

fig, axes = plt.subplots(1, len(thresholds), figsize=(20,5))

for i, ax in enumerate(axes):
  ax.imshow(canny_results[i], cmap='gray')
  ax.axis('off')
  ax.set_title(f'threshold1={thresholds[i][0]}, threshold2={thresholds[i][1]}')
